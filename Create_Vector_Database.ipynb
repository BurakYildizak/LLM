# %% [markdown]
# **Create Vector Database**

# %%
# !pip install -r requirements.txt
# Out:
# Ignoring protobuf: markers 'sys_platform == "darwin" and platform_machine != "arm64"' don't match your environment
# Ignoring protobuf: markers 'sys_platform == "darwin" and platform_machine == "arm64"' don't match your environment
# Ignoring bitsandbytes: markers 'sys_platform != "win32"' don't match your environment
# Requirement already satisfied: langchain==0.0.267 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 2)) (0.0.267)
# Requirement already satisfied: chromadb==0.4.6 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: pdfminer.six==20221105 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 4)) (20221105)
# Requirement already satisfied: InstructorEmbedding in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: sentence-transformers in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 6)) (2.2.2)
# Requirement already satisfied: faiss-cpu in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 7)) (1.7.4)
# Requirement already satisfied: huggingface_hub in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 8)) (0.19.4)
# Requirement already satisfied: transformers in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 9)) (4.35.2)
# Requirement already satisfied: protobuf==3.20.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 10)) (3.20.2)
# Requirement already satisfied: auto-gptq==0.2.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 13)) (0.2.2)
# Requirement already satisfied: docx2txt in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 14)) (0.8)
# Requirement already satisfied: unstructured in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 15)) (0.11.0)
# Requirement already satisfied: urllib3==1.26.6 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 19)) (1.26.6)
# Requirement already satisfied: accelerate in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 20)) (0.24.1)
# Requirement already satisfied: bitsandbytes-windows in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 22)) (0.37.5)
# Requirement already satisfied: click in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 23)) (8.1.7)
# Requirement already satisfied: flask in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 24)) (3.0.0)
# Requirement already satisfied: requests in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 25)) (2.31.0)
# Requirement already satisfied: streamlit in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 28)) (1.28.2)
# Requirement already satisfied: Streamlit-extras in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 29)) (0.0.9)
# Requirement already satisfied: openpyxl in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 32)) (3.1.2)
# Collecting jq (from -r requirements.txt (line 33))
#   Using cached jq-1.6.0.tar.gz (2.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: llama-cpp-python==0.1.83 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from -r requirements.txt (line 34)) (0.1.83)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from langchain==0.0.267->-r requirements.txt (line 2)) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from langchain==0.0.267->-r requirements.txt (line 2)) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from langchain==0.0.267->-r requirements.txt (line 2)) (3.9.0)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from langchain==0.0.267->-r requirements.txt (line 2)) (0.5.14)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.21 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from langchain==0.0.267->-r requirements.txt (line 2)) (0.0.66)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from langchain==0.0.267->-r requirements.txt (line 2)) (2.8.7)
# Requirement already satisfied: numpy<2,>=1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from langchain==0.0.267->-r requirements.txt (line 2)) (1.25.2)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from langchain==0.0.267->-r requirements.txt (line 2)) (1.2.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from langchain==0.0.267->-r requirements.txt (line 2)) (1.10.13)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from langchain==0.0.267->-r requirements.txt (line 2)) (8.2.3)
# Requirement already satisfied: chroma-hnswlib==0.7.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from chromadb==0.4.6->-r requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: fastapi<0.100.0,>=0.95.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from chromadb==0.4.6->-r requirements.txt (line 3)) (0.99.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.6->-r requirements.txt (line 3)) (0.24.0.post1)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from chromadb==0.4.6->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from chromadb==0.4.6->-r requirements.txt (line 3)) (4.7.1)
# Requirement already satisfied: pulsar-client>=3.1.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from chromadb==0.4.6->-r requirements.txt (line 3)) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from chromadb==0.4.6->-r requirements.txt (line 3)) (1.15.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from chromadb==0.4.6->-r requirements.txt (line 3)) (0.15.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from chromadb==0.4.6->-r requirements.txt (line 3)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from chromadb==0.4.6->-r requirements.txt (line 3)) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from chromadb==0.4.6->-r requirements.txt (line 3)) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from chromadb==0.4.6->-r requirements.txt (line 3)) (6.0.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from pdfminer.six==20221105->-r requirements.txt (line 4)) (2.0.4)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from pdfminer.six==20221105->-r requirements.txt (line 4)) (41.0.2)
# Requirement already satisfied: datasets in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from auto-gptq==0.2.2->-r requirements.txt (line 13)) (2.15.0)
# Requirement already satisfied: rouge in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from auto-gptq==0.2.2->-r requirements.txt (line 13)) (1.0.1)
# Requirement already satisfied: torch>=1.13.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from auto-gptq==0.2.2->-r requirements.txt (line 13)) (2.0.1)
# Requirement already satisfied: safetensors in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from auto-gptq==0.2.2->-r requirements.txt (line 13)) (0.4.0)
# Requirement already satisfied: diskcache>=5.6.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from llama-cpp-python==0.1.83->-r requirements.txt (line 34)) (5.6.3)
# Requirement already satisfied: torchvision in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from sentence-transformers->-r requirements.txt (line 6)) (0.15.2)
# Requirement already satisfied: scikit-learn in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from sentence-transformers->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: scipy in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from sentence-transformers->-r requirements.txt (line 6)) (1.11.4)
# Requirement already satisfied: nltk in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from sentence-transformers->-r requirements.txt (line 6)) (3.8.1)
# Requirement already satisfied: sentencepiece in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from sentence-transformers->-r requirements.txt (line 6)) (0.1.99)
# Requirement already satisfied: filelock in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from huggingface_hub->-r requirements.txt (line 8)) (3.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from huggingface_hub->-r requirements.txt (line 8)) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from huggingface_hub->-r requirements.txt (line 8)) (23.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from transformers->-r requirements.txt (line 9)) (2023.10.3)
# Requirement already satisfied: chardet in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured->-r requirements.txt (line 15)) (4.0.0)
# Requirement already satisfied: filetype in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured->-r requirements.txt (line 15)) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured->-r requirements.txt (line 15)) (0.4.27)
# Requirement already satisfied: lxml in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured->-r requirements.txt (line 15)) (4.9.2)
# Requirement already satisfied: tabulate in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured->-r requirements.txt (line 15)) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured->-r requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: emoji in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured->-r requirements.txt (line 15)) (2.8.0)
# Requirement already satisfied: python-iso639 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured->-r requirements.txt (line 15)) (2023.6.15)
# Requirement already satisfied: langdetect in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured->-r requirements.txt (line 15)) (1.0.9)
# Requirement already satisfied: rapidfuzz in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured->-r requirements.txt (line 15)) (3.5.2)
# Requirement already satisfied: backoff in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured->-r requirements.txt (line 15)) (2.2.1)
# Requirement already satisfied: wrapt in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured->-r requirements.txt (line 15)) (1.14.1)
# Requirement already satisfied: onnx in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 16)) (1.15.0)
# Requirement already satisfied: pdf2image in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 16)) (1.16.3)
# Requirement already satisfied: unstructured-inference==0.7.15 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 16)) (0.7.15)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured[pdf]->-r requirements.txt (line 16)) (0.3.12)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (0.3.4)
# Requirement already satisfied: python-multipart in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (0.0.6)
# Requirement already satisfied: opencv-python!=4.7.0.68 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (4.8.0.76)
# Requirement already satisfied: psutil in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from accelerate->-r requirements.txt (line 20)) (5.9.0)
# Requirement already satisfied: colorama in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from click->-r requirements.txt (line 23)) (0.4.6)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from flask->-r requirements.txt (line 24)) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from flask->-r requirements.txt (line 24)) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from flask->-r requirements.txt (line 24)) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from flask->-r requirements.txt (line 24)) (1.7.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from requests->-r requirements.txt (line 25)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from requests->-r requirements.txt (line 25)) (2023.11.17)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (5.1.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (5.3.2)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (6.0.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (2.1.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (9.4.0)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (14.0.1)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (2.8.2)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (13.7.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (0.10.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (6.3.2)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from streamlit->-r requirements.txt (line 28)) (2.1.6)
# Requirement already satisfied: et-xmlfile in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from openpyxl->-r requirements.txt (line 32)) (1.1.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.267->-r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.267->-r requirements.txt (line 2)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.267->-r requirements.txt (line 2)) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.267->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.267->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 28)) (4.17.3)
# Requirement already satisfied: toolz in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 28)) (0.12.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20221105->-r requirements.txt (line 4)) (1.15.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.267->-r requirements.txt (line 2)) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.267->-r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from fastapi<0.100.0,>=0.95.2->chromadb==0.4.6->-r requirements.txt (line 3)) (0.27.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 28)) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit->-r requirements.txt (line 28)) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from Jinja2>=3.1.2->flask->-r requirements.txt (line 24)) (2.1.1)
# Requirement already satisfied: coloredlogs in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.4.6->-r requirements.txt (line 3)) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.4.6->-r requirements.txt (line 3)) (23.5.26)
# Requirement already satisfied: sympy in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.4.6->-r requirements.txt (line 3)) (1.11.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 28)) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 28)) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from posthog>=2.4.0->chromadb==0.4.6->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from posthog>=2.4.0->chromadb==0.4.6->-r requirements.txt (line 3)) (1.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 28)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 28)) (2.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.0.267->-r requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: networkx in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from torch>=1.13.0->auto-gptq==0.2.2->-r requirements.txt (line 13)) (3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.4.6->-r requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.6->-r requirements.txt (line 3)) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.6->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.6->-r requirements.txt (line 3)) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.6->-r requirements.txt (line 3)) (12.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from beautifulsoup4->unstructured->-r requirements.txt (line 15)) (2.4)
# Requirement already satisfied: pyarrow-hotfix in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from datasets->auto-gptq==0.2.2->-r requirements.txt (line 13)) (0.5)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from datasets->auto-gptq==0.2.2->-r requirements.txt (line 13)) (0.3.7)
# Requirement already satisfied: xxhash in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from datasets->auto-gptq==0.2.2->-r requirements.txt (line 13)) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from datasets->auto-gptq==0.2.2->-r requirements.txt (line 13)) (0.70.15)
# Requirement already satisfied: joblib in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from nltk->sentence-transformers->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: pycparser in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->-r requirements.txt (line 4)) (2.21)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 28)) (5.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 28)) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 28)) (0.1.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb==0.4.6->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.267->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.6->-r requirements.txt (line 3)) (10.0)
# Requirement already satisfied: iopath in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (0.1.10)
# Requirement already satisfied: pdfplumber in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (0.10.3)
# Requirement already satisfied: effdet in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (0.4.1)
# Requirement already satisfied: pytesseract in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (0.3.10)
# Requirement already satisfied: mpmath>=0.19 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.4.6->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb==0.4.6->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: pyreadline3 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.6->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: timm>=0.9.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (0.9.11)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (2.0.7)
# Requirement already satisfied: omegaconf>=2.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (2.3.0)
# Requirement already satisfied: portalocker in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (2.8.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (4.24.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (4.9.3)
# Requirement already satisfied: matplotlib>=2.1.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (3.7.1)
# Requirement already satisfied: pywin32>=226 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from portalocker->iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (305.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\burak.yildizak\anaconda3\envs\test-env\lib\site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.15->unstructured[pdf]->-r requirements.txt (line 16)) (3.1.1)
# Building wheels for collected packages: jq
#   Building wheel for jq (pyproject.toml): started
#   Building wheel for jq (pyproject.toml): finished with status 'error'
# Failed to build jq
#   error: subprocess-exited-with-error
#
#   Building wheel for jq (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [5 lines of output]
#   running bdist_wheel
#   running build
#   running build_ext
#   Executing: ./configure CFLAGS=-fPIC --prefix=C:\Users\burak.yildizak\AppData\Local\Temp\pip-install-1z61gxzc\jq_7d76603fe53e442bb191db9eb4fa1b3d\_deps\build\onig-install-6.9.8
#   error: [WinError 2] The system cannot find the file specified
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for jq
# ERROR: Could not build wheels for jq, which is required to install pyproject.toml-based projects

# %%
import json
from pathlib import Path
from pprint import pprint
from langchain.document_loaders import JSONLoader
from langchain.text_splitter import Language, RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceInstructEmbeddings
from langchain.vectorstores import Chroma
from chromadb.config import Settings
import os
import logging
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor, as_completed
from langchain.docstore.document import Document
from langchain.document_loaders import CSVLoader, PDFMinerLoader, TextLoader, UnstructuredExcelLoader, Docx2txtLoader#,JSONLoader
from langchain.document_loaders import UnstructuredFileLoader, UnstructuredMarkdownLoader

# %%
INGEST_THREADS = os.cpu_count() or 8
DOCUMENT_MAP = {
    ".txt": TextLoader,
    ".md": UnstructuredMarkdownLoader,
    ".py": TextLoader,
    ".pdf": PDFMinerLoader,
    ".pdf": UnstructuredFileLoader,
    ".csv": CSVLoader,
    ".xls": UnstructuredExcelLoader,
    ".xlsx": UnstructuredExcelLoader,
    ".docx": Docx2txtLoader,
    ".doc": Docx2txtLoader,
    #".json": JSONLoader
}

# %%
def file_log(logentry):
   file1 = open("file_ingest.log","a")
   file1.write(logentry + "\n")
   file1.close()
   print(logentry + "\n")

# %%
def load_single_document(file_path: str) -> Document:
    # Loads a single document from a file path
    try:
       file_extension = os.path.splitext(file_path)[1]
       loader_class = DOCUMENT_MAP.get(file_extension)
       if loader_class:
           file_log(file_path + ' loaded.')
           loader = loader_class(file_path)
       else:
           file_log(file_path + ' document type is undefined.')
           raise ValueError("Document type is undefined")
       return loader.load()[0]
    except Exception as ex:
       file_log('%s loading error: \n%s' % (file_path, ex))
       return None

# %%
def load_document_batch(filepaths):
    logging.info("Loading document batch")
    # create a thread pool
    with ThreadPoolExecutor(len(filepaths)) as exe:
        # load files
        futures = [exe.submit(load_single_document, name) for name in filepaths]
        # collect data
        if futures is None:
           file_log(name + ' failed to submit')
           return None
        else:
           data_list = [future.result() for future in futures]
           # return data and file paths
           return (data_list, filepaths)

# %%
def load_documents(source_dir: str) -> list[Document]:
    # Loads all documents from the source documents directory, including nested folders
    paths = []
    for root, _, files in os.walk(source_dir):
        for file_name in files:
            print('Importing: ' + file_name)
            file_extension = os.path.splitext(file_name)[1]
            source_file_path = os.path.join(root, file_name)
            if file_extension in DOCUMENT_MAP.keys():
                paths.append(source_file_path)

    # Have at least one worker and at most INGEST_THREADS workers
    n_workers = min(INGEST_THREADS, max(len(paths), 1))
    chunksize = round(len(paths) / n_workers)
    docs = []
    with ProcessPoolExecutor(n_workers) as executor:
        futures = []
        # split the load operations into chunks
        for i in range(0, len(paths), chunksize):
            # select a chunk of filenames
            filepaths = paths[i : (i + chunksize)]
            # submit the task
            try:
               future = executor.submit(load_document_batch, filepaths)
            except Exception as ex:
               file_log('executor task failed: %s' % (ex))
               future = None
            if future is not None:
               futures.append(future)
        # process all results
        for future in as_completed(futures):
            # open the file and load the data
            try:
                contents, _ = future.result()
                docs.extend(contents)
            except Exception as ex:
                file_log('Exception: %s' % (ex))
                
    return docs

# %%
def split_documents(documents: list[Document]) -> tuple[list[Document], list[Document]]:
    # Splits documents for correct Text Splitter
    text_docs = []
    for doc in documents:
        if doc is not None:
           file_extension = os.path.splitext(doc.metadata["source"])[1]
           #if file_extension == ".json":
           #    json_docs.append(doc)
           #else:
           text_docs.append(doc)
    return text_docs

# %%
documents = load_documents('Data')
text_documents = split_documents(documents)
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
texts = text_splitter.split_documents(text_documents)
#texts.extend(json_splitter.split_documents(json_documents))
logging.info(f"Split into {len(texts)} chunks of text")
# Out:
# Importing: 10.53070-bbd.989668-1951903.pdf
# Exception: A process in the process pool was terminated abruptly while the future was running or pending.

# %%
# Create embeddings
embeddings = HuggingFaceInstructEmbeddings(model_name="all-MiniLM-L6-v2")
print(texts)
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512
# []

# %%
CHROMA_SETTINGS = Settings(anonymized_telemetry=False,is_persistent=True)

db = Chroma.from_documents(texts,
    embeddings,
    persist_directory="DB",
    client_settings=CHROMA_SETTINGS,
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 CHROMA_SETTINGS = Settings(anonymized_telemetry=False,is_persistent=True)
# ----> 3 db = Chroma.from_documents(texts,
#       4     embeddings,
#       5     persist_directory="DB",
#       6     client_settings=CHROMA_SETTINGS,
#       7 )
#
# File ~\Anaconda3\envs\test-env\Lib\site-packages\langchain\vectorstores\chroma.py:613, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     611 texts = [doc.page_content for doc in documents]
#     612 metadatas = [doc.metadata for doc in documents]
# --> 613 return cls.from_texts(
#     614     texts=texts,
#     615     embedding=embedding,
#     616     metadatas=metadatas,
#     617     ids=ids,
#     618     collection_name=collection_name,
#     619     persist_directory=persist_directory,
#     620     client_settings=client_settings,
#     621     client=client,
#     622     collection_metadata=collection_metadata,
#     623     **kwargs,
#     624 )
#
# File ~\Anaconda3\envs\test-env\Lib\site-packages\langchain\vectorstores\chroma.py:577, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     549 """Create a Chroma vectorstore from a raw documents.
#     550
#     551 If a persist_directory is specified, the collection will be persisted there.
#    (...)
#     566     Chroma: Chroma vectorstore.
#     567 """
#     568 chroma_collection = cls(
#     569     collection_name=collection_name,
#     570     embedding_function=embedding,
#    (...)
#     575     **kwargs,
#     576 )
# --> 577 chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#     578 return chroma_collection
#
# File ~\Anaconda3\envs\test-env\Lib\site-packages\langchain\vectorstores\chroma.py:187, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     185 texts = list(texts)
#     186 if self._embedding_function is not None:
# --> 187     embeddings = self._embedding_function.embed_documents(texts)
#     188 if metadatas:
#     189     # fill metadatas with empty dicts if somebody
#     190     # did not specify metadata for all texts
#     191     length_diff = len(texts) - len(metadatas)
#
# File ~\Anaconda3\envs\test-env\Lib\site-packages\langchain\embeddings\huggingface.py:169, in HuggingFaceInstructEmbeddings.embed_documents(self, texts)
#     160 """Compute doc embeddings using a HuggingFace instruct model.
#     161
#     162 Args:
#    (...)
#     166     List of embeddings, one for each text.
#     167 """
#     168 instruction_pairs = [[self.embed_instruction, text] for text in texts]
# --> 169 embeddings = self.client.encode(instruction_pairs, **self.encode_kwargs)
#     170 return embeddings.tolist()
#
# File ~\Anaconda3\envs\test-env\Lib\site-packages\InstructorEmbedding\instructor.py:524, in INSTRUCTOR.encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     521 self.to(device)
#     523 all_embeddings = []
# --> 524 if isinstance(sentences[0],list):
#     525     lengths = []
#     526     for sen in sentences:
#
# IndexError: list index out of range

# %%
import os
import logging
import click
import torch
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceInstructEmbeddings
from langchain.llms import HuggingFacePipeline
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler  # for streaming response
from langchain.callbacks.manager import CallbackManager
from langchain.vectorstores import Chroma
from huggingface_hub import hf_hub_download
#from prompt_template_utils import get_prompt_template
from transformers import (
    GenerationConfig,
    pipeline,
)
callback_manager = CallbackManager([StreamingStdOutCallbackHandler()])
from langchain.llms import LlamaCpp
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate
MaxNewTokens=4096

# %%
system_prompt = """You are a helpful assistant, you will use the provided context to answer user questions.
Read the given context before answering questions and think step by step. If you can not answer a user question based on
the provided context, inform the user. Do not use any other information for answering user. Provide a detailed answer to the question."""

def get_prompt_template(system_prompt=system_prompt, promptTemplate_type=None, history=False):
    if promptTemplate_type == "llama":
        B_INST, E_INST = "[INST]", "[/INST]"
        B_SYS, E_SYS = "<<SYS>>\n", "\n<</SYS>>\n\n"
        SYSTEM_PROMPT = B_SYS + system_prompt + E_SYS
        if history:
            instruction = """
            Context: {history} \n {context}
            User: {question}"""

            prompt_template = B_INST + SYSTEM_PROMPT + instruction + E_INST
            prompt = PromptTemplate(input_variables=["history", "context", "question"], template=prompt_template)
        else:
            instruction = """
            Context: {context}
            User: {question}"""

            prompt_template = B_INST + SYSTEM_PROMPT + instruction + E_INST
            prompt = PromptTemplate(input_variables=["context", "question"], template=prompt_template)
    else:
        # change this based on the model you have selected.
        if history:
            prompt_template = (
                system_prompt
                + """

            Context: {history} \n {context}
            User: {question}
            Answer:"""
            )
            prompt = PromptTemplate(input_variables=["history", "context", "question"], template=prompt_template)
        else:
            prompt_template = (
                system_prompt
                + """

            Context: {context}
            User: {question}
            Answer:"""
            )
            prompt = PromptTemplate(input_variables=["context", "question"], template=prompt_template)

    memory = ConversationBufferMemory(input_key="question", memory_key="history")

    return (
        prompt,
        memory,
    )

# %%
def load_quantized_model_gguf_ggml(model_id, model_basename, device_type, logging):
    path="./models"

    try:
        logging.info("Using Llamacpp for GGUF/GGML quantized models")
        model_path = hf_hub_download(
            repo_id=model_id,
            filename=model_basename,
            resume_download=True,
            cache_dir=path,
        )
        kwargs = {
            "model_path": model_path,
            "n_ctx": MaxNewTokens,
            "max_tokens": MaxNewTokens,
            "n_batch": 512,  # set this based on your GPU & CPU RAM
        }
        if device_type.lower() == "mps":
            kwargs["n_gpu_layers"] = 1
        if device_type.lower() == "cuda":
            kwargs["n_gpu_layers"] = 100  # set this based on your GPU

        return LlamaCpp(**kwargs)
    except:
        if "ggml" in model_basename:
            logging.INFO("If you were using GGML model, LLAMA-CPP Dropped Support, Use GGUF Instead")
        return None

# %%
def load_model(device_type, model_id, model_basename=None, LOGGING=logging):

    logging.info(f"Loading Model: {model_id}, on: {device_type}")
    logging.info("This action can take a few minutes!")

    if model_basename is not None:
        if ".gguf" in model_basename.lower():
            llm = load_quantized_model_gguf_ggml(model_id, model_basename, device_type, LOGGING)
            #return llm

    # # Load configuration from the model to avoid warnings
    # generation_config = GenerationConfig.from_pretrained(model_id)
    # # see here for details:
    # # https://huggingface.co/docs/transformers/
    # # main_classes/text_generation#transformers.GenerationConfig.from_pretrained.returns

    # # Create a pipeline for text generation
    # pipe = pipeline(
    #     "text-generation",
    #     model=model,
    #     tokenizer=tokenizer,
    #     max_length=MaxNewTokens,
    #     temperature=0.2,
    #     # top_p=0.95,
    #     repetition_penalty=1.15,
    #     generation_config=generation_config,
    # )

    # local_llm = HuggingFacePipeline(pipeline=pipe)
    # logging.info("Local LLM Loaded")

    return llm

# %%
MODEL_ID = "TheBloke/Llama-2-7b-Chat-GGUF"
MODEL_BASENAME = "llama-2-7b-chat.Q4_K_M.gguf"
EMBEDDING_MODEL_NAME = "all-MiniLM-L6-v2"

SOURCE_DIRECTORY = f"/content/Data"

PERSIST_DIRECTORY = "/content/DB"
def retrieval_qa_pipline(device_type, use_history, promptTemplate_type="llama"):

    embeddings = HuggingFaceInstructEmbeddings(model_name=EMBEDDING_MODEL_NAME, model_kwargs={"device": device_type})
    # uncomment the following line if you used HuggingFaceEmbeddings in the ingest.py
    # embeddings = HuggingFaceEmbeddings(model_name=EMBEDDING_MODEL_NAME)

    # load the vectorstore
    db = Chroma(
        persist_directory=PERSIST_DIRECTORY,
        embedding_function=embeddings,
        client_settings=CHROMA_SETTINGS
    )
    retriever = db.as_retriever()

    # get the prompt template and memory if set by the user.
    prompt, memory = get_prompt_template(promptTemplate_type=promptTemplate_type, history=use_history)

    # load the llm pipeline
    llm = load_model(device_type, model_id=MODEL_ID, model_basename=MODEL_BASENAME, LOGGING=logging)

    if use_history:
        qa = RetrievalQA.from_chain_type(
            llm=llm,
            chain_type="stuff",  # try other chains types as well. refine, map_reduce, map_rerank
            retriever=retriever,
            return_source_documents=True,  # verbose=True,
            callbacks=callback_manager,
            chain_type_kwargs={"prompt": prompt, "memory": memory},
        )
    else:
        qa = RetrievalQA.from_chain_type(
            llm=llm,
            chain_type="stuff",  # try other chains types as well. refine, map_reduce, map_rerank
            retriever=retriever,
            return_source_documents=True,  # verbose=True,
            callbacks=callback_manager,
            chain_type_kwargs={
                "prompt": prompt,
            },
        )

    return qa

# %%
retriever = db.as_retriever()

# get the prompt template and memory if set by the user.
qa = retrieval_qa_pipline(use_history=True,device_type="cpu")
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512
# llama-2-7b-chat.Q4_K_M.gguf:   0%|          | 0.00/4.08G [00:00<?, ?B/s]
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %%
while True:
        query = input("\nEnter a query: ")
        if query == "exit":
            break
        # Get the answer from the chain
        res = qa(query)
        answer, docs = res["result"], res["source_documents"]

        # Print the result
        print("\n\n> Question:")
        print(query)
        print("\n> Answer:")
        print(answer)
# Out:
# > Question:
# Is sonoo married?
#
# > Answer:
#   Sure, I'm happy to help! Based on the provided context, we know that Sonoo is an employee with a name of "sonoo" and a salary of $56,000. Additionally, we know that he is married. So, the answer to your question is:
# Yes, Sonoo is married.
